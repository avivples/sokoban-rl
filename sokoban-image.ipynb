# %% [markdown]
# # Final Project - Reinforcements Learning
#
# ---
# <br>
#
# ### Name and ID:
# Student: Aviv Ples 318357233
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !apt-get update
# !apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym==0.22
# !pip install pygame
# !apt-get install python-opengl -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym_sokoban
# !git clone https://github.com/avivg7/sokoban-so.git
# !unzip /content/sokoban-so/Compress.zip

# !pip install mlflow==2.5.0 dagshub opencv-python

# %%
# !pip install mlflow==2.5.0 dagshub opencv-python
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting mlflow==2.5.0
#   Using cached mlflow-2.5.0-py3-none-any.whl (18.2 MB)
# Collecting dagshub
#   Using cached dagshub-0.3.5-py3-none-any.whl (180 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (8.1.7)
# Requirement already satisfied: cloudpickle<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (2.2.1)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.5.0)
#   Using cached databricks-cli-0.17.7.tar.gz (83 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (0.4)
# Collecting gitpython<4,>=2.1.0 (from mlflow==2.5.0)
#   Using cached GitPython-3.1.32-py3-none-any.whl (188 kB)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (6.0.1)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (3.20.3)
# Requirement already satisfied: pytz<2024 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (2023.3)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (2.31.0)
# Requirement already satisfied: packaging<24 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (23.1)
# Requirement already satisfied: importlib-metadata!=4.7.0,<7,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (6.8.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (0.4.4)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.5.0)
#   Using cached alembic-1.11.3-py3-none-any.whl (225 kB)
# Collecting docker<7,>=4.0.0 (from mlflow==2.5.0)
#   Using cached docker-6.1.3-py3-none-any.whl (148 kB)
# Requirement already satisfied: Flask<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (2.2.5)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (1.23.5)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (1.10.1)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (1.5.3)
# Collecting querystring-parser<2 (from mlflow==2.5.0)
#   Using cached querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (2.0.20)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (1.2.2)
# Requirement already satisfied: pyarrow<13,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (9.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (3.4.4)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (3.7.1)
# Collecting gunicorn<21 (from mlflow==2.5.0)
#   Using cached gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.10/dist-packages (from mlflow==2.5.0) (3.1.2)
# Collecting fusepy>=3 (from dagshub)
#   Using cached fusepy-3.0.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from dagshub) (1.4.4)
# Collecting httpx~=0.23.0 (from dagshub)
#   Using cached httpx-0.23.3-py3-none-any.whl (71 kB)
# Collecting rich[jupyter]~=13.1.0 (from dagshub)
#   Using cached rich-13.1.0-py3-none-any.whl (238 kB)
# Collecting dacite~=1.6.0 (from dagshub)
#   Using cached dacite-1.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: tenacity~=8.2.2 in /usr/local/lib/python3.10/dist-packages (from dagshub) (8.2.3)
# Collecting gql[requests] (from dagshub)
#   Using cached gql-3.4.1-py2.py3-none-any.whl (65 kB)
# Collecting dataclasses-json (from dagshub)
#   Using cached dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting treelib~=1.6.4 (from dagshub)
#   Using cached treelib-1.6.4-py3-none-any.whl (18 kB)
# Collecting pathvalidate~=3.0.0 (from dagshub)
#   Using cached pathvalidate-3.0.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from dagshub) (2.8.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.5.0)
#   Using cached Mako-1.2.4-py3-none-any.whl (78 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic!=1.10.0,<2->mlflow==2.5.0) (4.7.1)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/lib/python3/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0) (2.3.0)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0) (1.16.0)
# Collecting urllib3<2.0.0,>=1.26.7 (from databricks-cli<1,>=0.8.7->mlflow==2.5.0)
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.1/143.1 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from docker<7,>=4.0.0->mlflow==2.5.0) (1.6.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow==2.5.0) (2.3.7)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3->mlflow==2.5.0) (2.1.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=2.1.0->mlflow==2.5.0)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.10/dist-packages (from gunicorn<21->mlflow==2.5.0) (67.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx~=0.23.0->dagshub) (2023.7.22)
# Collecting httpcore<0.17.0,>=0.15.0 (from httpx~=0.23.0->dagshub)
#   Downloading httpcore-0.16.3-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 10.1 MB/s eta 0:00:00
# Collecting rfc3986[idna2008]<2,>=1.3 (from httpx~=0.23.0->dagshub)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx~=0.23.0->dagshub) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.5.0) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2<4,>=2.11->mlflow==2.5.0) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4->mlflow==2.5.0) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0) (3.4)
# Collecting commonmark<0.10.0,>=0.9.0 (from rich[jupyter]~=13.1.0->dagshub)
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from rich[jupyter]~=13.1.0->dagshub) (2.16.1)
# Requirement already satisfied: ipywidgets<8.0.0,>=7.5.1 in /usr/local/lib/python3.10/dist-packages (from rich[jupyter]~=13.1.0->dagshub) (7.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.5.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2->mlflow==2.5.0) (3.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.5.0) (2.0.2)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting graphql-core<3.3,>=3.2 (from gql[requests]->dagshub)
#   Downloading graphql_core-3.2.3-py3-none-any.whl (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.9/202.9 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.10/dist-packages (from gql[requests]->dagshub) (1.9.2)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting requests-toolbelt<1,>=0.9.1 (from gql[requests]->dagshub)
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.5.0)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting h11<0.15,>=0.13 (from httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub) (3.7.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.6.5)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.0.8)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub) (6.0.4)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.17.0,>=0.15.0->httpx~=0.23.0->dagshub) (1.1.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.3.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.0.39)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.8.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.8.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.3.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.5.7)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (3.10.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (6.0.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (4.19.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.9.2)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.4.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<8.0.0,>=7.5.1->rich[jupyter]~=13.1.0->dagshub) (2.21)
# Building wheels for collected packages: databricks-cli, fusepy
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.17.7-py3-none-any.whl size=143855 sha256=ab835bc12987b7ab8d0177b22434148274e271d6d0b25f5b992feb09a05d4be4
#   Stored in directory: /root/.cache/pip/wheels/ae/63/93/5402c1a09c1868a59d0b05013484e07af97a9d7b3dbd5bd39a
#   Building wheel for fusepy (setup.py) ... done
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10486 sha256=7ad59e5afeee72f467021e8d931d645bf177431b169128023873b0ddabe79e3b
#   Stored in directory: /root/.cache/pip/wheels/c0/18/f6/f0d6be9d0435e2677ce5cc758e91da50053dce456a346f08c5
# Successfully built databricks-cli fusepy
# Installing collected packages: rfc3986, fusepy, commonmark, urllib3, treelib, smmap, rich, querystring-parser, pathvalidate, mypy-extensions, marshmallow, Mako, jedi, h11, gunicorn, graphql-core, dacite, backoff, typing-inspect, httpcore, gql, gitdb, alembic, requests-toolbelt, httpx, gitpython, docker, dataclasses-json, databricks-cli, mlflow, dagshub
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.4
#     Uninstalling urllib3-2.0.4:
#       Successfully uninstalled urllib3-2.0.4
#   Attempting uninstall: rich
#     Found existing installation: rich 13.5.2
#     Uninstalling rich-13.5.2:
#       Successfully uninstalled rich-13.5.2
# Successfully installed Mako-1.2.4 alembic-1.11.3 backoff-2.2.1 commonmark-0.9.1 dacite-1.6.0 dagshub-0.3.5 databricks-cli-0.17.7 dataclasses-json-0.5.14 docker-6.1.3 fusepy-3.0.1 gitdb-4.0.10 gitpython-3.1.32 gql-3.4.1 graphql-core-3.2.3 gunicorn-20.1.0 h11-0.14.0 httpcore-0.16.3 httpx-0.23.3 jedi-0.19.0 marshmallow-3.20.1 mlflow-2.5.0 mypy-extensions-1.0.0 pathvalidate-3.0.0 querystring-parser-1.2.4 requests-toolbelt-0.10.1 rfc3986-1.5.0 rich-13.1.0 smmap-5.0.0 treelib-1.6.4 typing-inspect-0.9.0 urllib3-1.26.16

# %% [markdown]
# # Imports

# %%
import numpy as np
import gym
from gym import logger as gymlogger
from gym.utils import seeding
from gym import error, spaces, utils
gymlogger.set_level(40) # error only
from soko_pap import *
import glob
import io
import base64
import os
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
from pyvirtualdisplay import Display
from IPython.display import HTML
from IPython import display as ipythondisplay
import pygame
import pyvirtualdisplay
import imageio
import IPython
import time

import copy

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import pickle
import imageio
from base64 import b64encode

import cv2
from IPython.display import clear_output

# %%
import warnings
warnings.filterwarnings("ignore")
# %autosave 5
# Out:
# Autosaving every 5 seconds

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
  """Embeds an mp4 file in the notebook."""
  video = open(filename,'rb').read()
  b64 = base64.b64encode(video)
  tag = '''
  <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
  Your browser does not support the video tag.
  </video>'''.format(b64.decode())

  return IPython.display.HTML(tag)
display = pyvirtualdisplay.Display(visible=0, size=(1400, 900)).start()

# %% [markdown]
# Function - given an environment it will print us the details about observation, actions, agent's position and boxes locations

# %%
def print_env_det(env):
  print(f'Observation space: {env.observation_space}'
      f'\nAction space: {env.action_space}'
      f'\nPlayer position:{env.player_position}'
      f'\nBox location: {find_box_location(env)}')

# %% [markdown]
# Function - given an environment it will return the indexes position and boxes locations

# %%
def find_box_location(env):
    idx = np.argmax(env.room_state == 4)
    if env.room_state.flat[idx] == 4:
        return np.unravel_index(idx, env.room_state.shape)
    return None

# %% [markdown]
# # MLFLOW

# %%
#@markdown Enter the DAGsHub repository owner name:
DAGSHUB_REPO_OWNER= "aviv.ples" #@param {type:"string"}

#@markdown Enter the DAGsHub repository name:
DAGSHUB_REPO_NAME= "sokoban-rl" #@param {type:"string"}

#@markdown Enter the username of your DAGsHub account:
DAGSHUB_USER_NAME = "aviv.ples" #@param {type:"string"}

DAGSHUB_TOKEN = "eb1587fdb4b2ef917e728f506d8bc187a67d1c93"

# %%
# MLFLOW

import mlflow
import os

os.environ['MLFLOW_TRACKING_USERNAME'] = DAGSHUB_USER_NAME
os.environ['MLFLOW_TRACKING_PASSWORD'] = DAGSHUB_TOKEN
os.environ['MLFLOW_TRACKING_URI'] = f'https://dagshub.com/{DAGSHUB_REPO_OWNER}/{DAGSHUB_REPO_NAME}.mlflow'

print(os.getenv('MLFLOW_TRACKING_URI'))
# Out:
# https://dagshub.com/aviv.ples/sokoban-rl.mlflow

# %% [markdown]
# # Functions

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# Set the PyTorch device to either "cuda" if GPU is available, or CPU otherwise. If you GPU is available, using it can significantly speed up the computations required for training deep neural networks.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# The replay memory buffer is used to store the experiences of an agent while it runs within the env. We will use the buffer sampling transitions from the it and using them to update the network's parameters during the training.

# %%
class SumTree:
    def __init__(self, capacity):
        self.capacity = capacity
        self.tree = np.zeros(2 * capacity - 1)
        self.data = np.zeros(capacity, dtype=object)
        self.write = 0

    def _propagate(self, idx, change):
        parent = (idx - 1) // 2
        self.tree[parent] += change
        if parent != 0:
            self._propagate(parent, change)

    def _retrieve(self, idx, s):
        left = 2 * idx + 1
        right = left + 1
        if left >= len(self.tree):
            return idx
        if s <= self.tree[left]:
            return self._retrieve(left, s)
        else:
            return self._retrieve(right, s - self.tree[left])

    def total_priority(self):
        return self.tree[0]

    def add(self, priority, data):
        idx = self.write + self.capacity - 1
        self.data[self.write] = data
        self.update(idx, priority)
        self.write = (self.write + 1) % self.capacity

    def update(self, idx, priority):
        change = priority - self.tree[idx]
        self.tree[idx] = priority
        self._propagate(idx, change)

    def get(self, s):
        idx = self._retrieve(0, s)
        dataIdx = idx - self.capacity + 1
        return (idx, self.tree[idx], self.data[dataIdx])

# %%
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

class ReplayMemory:
    def __init__(self, capacity, alpha=0.6, beta=0.4):
        self.alpha = alpha
        self.beta = beta
        self.tree = SumTree(capacity)
        self.capacity = capacity
        self.e = 0.01
        self.a = 0.6
        self.obs = None
        self.action = None
        self.reward = None
        self.done = None
        self.next_idx = 0
        self.num_in_buffer = 0

    def push(self, state, action, next_state, reward):
        max_priority = np.max(self.tree.tree[-self.tree.capacity:])
        if max_priority == 0:
            max_priority = 1
        frame_idx = self.store_frame(state)
        self.store_effect(frame_idx, action, reward, False)
        self.tree.add(max_priority, Transition(state, action, next_state, reward))

    def sample(self, batch_size):
        batch = []
        idxs = []
        segment = self.tree.total_priority() / batch_size
        priorities = []

        for i in range(batch_size):
            a = segment * i
            b = segment * (i + 1)
            value = np.random.uniform(a, b)
            index, priority, data = self.tree.get(value)
            priorities.append(priority)
            batch.append(data)
            idxs.append(index)

        sampling_probabilities = priorities / self.tree.total_priority()
        is_weight = np.power(self.tree.capacity * sampling_probabilities, -self.beta)
        is_weight /= is_weight.max()

        return batch, idxs, is_weight

    def update(self, idxs, errors):
        priorities = errors + self.e
        priorities = np.power(priorities, self.a)
        for idx, priority in zip(idxs, priorities):
            self.tree.update(idx, priority)

    def store_frame(self, frame):
        if self.obs is None:
            self.obs = np.empty([self.capacity] + list(frame.shape), dtype=np.uint8)
            self.action = np.empty([self.capacity], dtype=np.int32)
            self.reward = np.empty([self.capacity], dtype=np.float32)
            self.done = np.empty([self.capacity], dtype=np.bool)

        if isinstance(frame, torch.Tensor):
            frame = frame.cpu().numpy()

        self.obs[self.next_idx] = frame
        ret = self.next_idx
        self.next_idx = (self.next_idx + 1) % self.capacity
        self.num_in_buffer = min(self.capacity, self.num_in_buffer + 1)
        return ret

    def store_effect(self, idx, action, reward, done):
        self.action[idx] = action
        self.reward[idx] = reward
        self.done[idx] = done

    def __len__(self):
        return self.tree.write

# %% [markdown]
# Rescales each frame to size 112x112 with grayscale. The resulting observation is a NumPy array with shape (112, 112, 1).

# %%
class Rescale112x112(gym.ObservationWrapper):
    """
    Downsamples/Rescales each frame to size 112x112
    """
    def __init__(self, env=None):
        super(Rescale112x112, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(112, 112, 1), dtype=np.uint8)

    def observation(self, obs):
        return Rescale112x112.process(obs)

    @staticmethod
    def process(frame):
        resized_screen = cv2.resize(frame, (112, 112), interpolation=cv2.INTER_AREA)
        gray_screen = cv2.cvtColor(resized_screen, cv2.COLOR_RGB2GRAY)
        return np.expand_dims(gray_screen, axis=-1).astype(np.uint8)

# %% [markdown]
# To reduce computation time preserving important visual information in the observations, we repeat each action over skip number of frames and return only every skip-th frame while taking the maximum pixel values across the skipped frames.

# %%
class MaxAndSkipEnv(gym.Wrapper):
    """
    Each action of the agent is repeated over skip frames
    return only every `skip`-th frame
    """
    def __init__(self, env=None, skip=4):
        super().__init__(env)
        self._obs_buffer = deque(maxlen=2)
        self._skip = skip

    def step(self, action):
        total_reward = 0.0
        done = None
        for _ in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            self._obs_buffer.append(obs)
            total_reward += reward
            if done:
                break
        max_frame = np.maximum(self._obs_buffer[0], self._obs_buffer[1])
        return max_frame, total_reward, done, info

    def reset(self, **kwargs):
        self._obs_buffer.clear()
        obs = self.env.reset(**kwargs)
        self._obs_buffer.append(obs)
        return obs

# %% [markdown]
# Convert each observation to a PyTorch tensor

# %%
class ImageToPyTorch(gym.ObservationWrapper):
    """
    Each frame is converted to PyTorch tensors
    """
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(old_shape[-1], old_shape[0], old_shape[1]), dtype=np.float32)

    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)

# %% [markdown]
# Create a buffer of size n_steps that stores every k-th frame of the environment observation.

# %%
class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(low=np.tile(old_space.low, (n_steps, 1, 1)),
                                                high=np.tile(old_space.high, (n_steps, 1, 1)), dtype=dtype)
        self.n_steps = n_steps

    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low, dtype=self.dtype)
        obs = self.env.reset()
        self.buffer[-1] = obs
        return self.observation(obs)

    def observation(self, observation):
        self.buffer = np.roll(self.buffer, shift=-1, axis=0)
        self.buffer[-1] = observation
        return self.buffer

# %% [markdown]
# Normalize pixel values in each observation to be in the range of 0 to 1.

# %%
class PixelNormalization(gym.ObservationWrapper):
    """
    Normalize pixel values in frame --> 0 to 1
    """
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0

# %% [markdown]
# Create proper env, post all pre-processing:

# %%
def create_env(env):
    env = MaxAndSkipEnv(env)
    env = Rescale112x112(env)
    env = ImageToPyTorch(env)
    env = BufferWrapper(env, 4)
    env = PixelNormalization(env)
    return env

# %% [markdown]
# ## Models

# %%
class DQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DQN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)
        self.fc = nn.Sequential(
            nn.Linear(conv_out_size, 512),
            nn.ReLU(),
            nn.Linear(512, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

# %%
class NoImageDQN(nn.Module):
    def __init__(self, state_shape, n_actions):
        super(NoImageDQN, self).__init__()
        input_channels, env_dim, _ = state_shape

        self.conv = nn.Sequential(
            nn.Conv2d(input_channels, 16, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=1),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = (env_dim - 2*3)
        self.fc = nn.Sequential(
            nn.Linear(32 * conv_out_size * conv_out_size, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions)
        )

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        return self.fc(conv_out)

# %%
class DuelingDQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(DuelingDQN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)

        # Value stream
        self.value_stream = nn.Sequential(
            nn.Linear(conv_out_size, 256),
            nn.ReLU(),
            nn.Linear(256, 1)
        )

        # Advantage stream
        self.advantage_stream = nn.Sequential(
            nn.Linear(conv_out_size, 256),
            nn.ReLU(),
            nn.Linear(256, n_actions)
        )

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        conv_out = self.conv(x).view(x.size()[0], -1)
        value = self.value_stream(conv_out)
        advantage = self.advantage_stream(conv_out)
        q_values = value + (advantage - advantage.mean(dim=1, keepdim=True))
        return q_values

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Convergence Threshold
# If the policy is such that in the previous 20 iterations both the rewards sum and the duration averages has stayed appx. the same as the last one, the policy has convereged. In addtion, we demand that the latest reward will be over 5, since in trial and error iterations we have seen that the final reward for the optimal solution is set around 6.

# %%
def exponential_moving_average(data, alpha=0.1):
    ema = [data[0]]
    for i in range(1, len(data)):
        ema.append(alpha * data[i] + (1 - alpha) * ema[-1])
    return ema

def check_convergence(i_episode, episode_rewards, episode_durations, n=20, initial_reward_threshold=8, variance_threshold=1.0, duration_threshold=20):
    if len(episode_rewards) < n + 1:
        return False

    # Calculate the exponential moving averages for rewards and durations
    ema_rewards = exponential_moving_average(episode_rewards)
    ema_durations = exponential_moving_average(episode_durations)

    mean_reward = np.mean(ema_rewards[-n:])
    reward_variance = np.var(ema_rewards[-n:])
    mean_duration = np.mean(ema_durations[-n:])

    # Adaptive threshold based on the progress of training
    adaptive_reward_threshold = max(initial_reward_threshold - i_episode * 0.01, 4)

    if mean_reward < adaptive_reward_threshold or reward_variance > variance_threshold or mean_duration > duration_threshold:
        return False

    print(f"Policy has converged after {i_episode} episodes! The final episode_rewards sum is {episode_rewards[-1]}, and the final duration is {episode_durations[-1]}")
    return True

# %% [markdown]
# ### Optimize Model

# %%
def optimize_model(batch_size, gamma, optimizer, policy_net, target_net, memory):
    if len(memory) < batch_size:
        return
    transitions, idxs, is_weights = memory.sample(batch_size)
    batch = Transition(*zip(*transitions))
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None, batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([torch.tensor(s, dtype=torch.float32, device=device) for s in batch.next_state if s is not None])
    state_batch = torch.cat([torch.tensor(s, dtype=torch.float32, device=device) for s in batch.state])
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    state_action_values = policy_net(state_batch).gather(1, action_batch)

    next_state_values = torch.zeros(batch_size, device=device)
    with torch.no_grad():
        next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0]
    expected_state_action_values = (next_state_values * gamma) + reward_batch

    # Compute TD error
    td_errors = (expected_state_action_values.unsqueeze(1) - state_action_values).squeeze().detach().cpu().numpy()

    # Update priorities in the memory
    memory.update(idxs, np.abs(td_errors))

    # Compute Huber loss with importance sampling weights
    criterion = nn.SmoothL1Loss(reduction='none')
    loss = criterion(state_action_values, expected_state_action_values.unsqueeze(1))
    loss = (torch.tensor(is_weights, device=device, dtype=torch.float32) * loss).mean()

    optimizer.zero_grad()
    loss.backward()
    torch.nn.utils.clip_grad_value_(policy_net.parameters(), 100)
    optimizer.step()

# %% [markdown]
# ### Plot Results

# %%
def plot_results(res_list, duration_mode=False, add_mean_and_std=False, log=False, run_name=None):
    if duration_mode:
        y = 'Duration'
    else:
        y = 'Rewards'
    fig = plt.figure(figsize=(20, 12))
    ax = fig.add_subplot(111)
    ax.set_xlabel('Episode', fontsize=14)
    ax.set_ylabel(y, fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.plot(res_list, color='#0072BD', linewidth=2)
    ax.grid(linestyle='--', linewidth=0.5, alpha=0.7)

    ax.set_title(f'{run_name} {y}', fontsize=16)

    if add_mean_and_std:
        # Add mean and standard deviation to the plot
        res_mean = np.mean(res_list)
        res_std = np.std(res_list)
        ax.axhline(res_mean, color='#D95319', linestyle='--', linewidth=2, label='Mean')
        ax.fill_between(range(len(res_list)), res_list-res_std, res_list+res_std, color='#EDB120', alpha=0.2, label='Std Dev')
        ax.legend(loc='best', fontsize=12)
    if log:
        mlflow.log_figure(fig, f"{run_name}_{y}.png")
    plt.show()

# %% [markdown]
# ### Select Action

# %%
def select_action(state, env, policy_net, epsilon = 0.1):
    sample = random.random()
    if sample > epsilon:
        with torch.no_grad():
            state = torch.tensor(state, dtype=torch.float32, device=device)
            return policy_net(state).max(1)[1].view(1, 1)
    else:
        return torch.tensor([[env.action_space.sample()]], device=device, dtype=torch.long)

# %% [markdown]
# ### Reward manipulation
# To shorten training times on this task, we added the a reward manipulation logic. In each reward caclulation we calculate the previous Manhatten distance between the box location and the target location (before the action), as well and the current distance (after the action). If the distance has decreased, than generally we assume that the action was a positive action, and give it a positive boost. Otherwise, we give it a negative boost. If the action completed the game, we give an additional boost.

# %%
def apply_reward_manipulation(reward, box_positions, next_box_positions, end_goal_positions, done):
    # Initialize manipulated reward
    manip_reward = reward

    total_curr_distance = sum(min(manhattan_distance(box_pos, goal_pos) for goal_pos in end_goal_positions) for box_pos in box_positions)
    total_next_distance = sum(min(manhattan_distance(box_pos, goal_pos) for goal_pos in end_goal_positions) for box_pos in next_box_positions)

    if total_next_distance < total_curr_distance:
        manip_reward += 0.5  # Bonus for reducing total distance
    elif total_next_distance > total_curr_distance:
        manip_reward -= 0.5  # Penalty for increasing total distance

    return manip_reward


def manhattan_distance(agent_pos, box_pos):
      """
      Calculate the Manhattan distance between agent position and box position
      """
      return abs(agent_pos[0] - box_pos[0]) + abs(agent_pos[1] - box_pos[1])

# %%
def find_end_goal_positions(room_state):
    rows, cols = np.where(room_state == 2)
    return [(row, col) for row, col in zip(rows, cols)]

def find_box_positions(room_state):
    rows, cols = np.where(room_state == 4)
    return [(row, col) for row, col in zip(rows, cols)]

# %% [markdown]
# ### Training

# %%
def train(env, model, run_name, memory, optimizer, policy_net, target_net, batch_size, num_episodes, max_num_steps_per_episode, tau=0.005, gamma=0.99, epsilon_decay_exp=False, epsilon_decay_linear=False, epsilon=0.1, epsilon_decay_factor=0.98, reward_manipulation=False, seed_env=True):
    episode_durations = []
    episode_rewards = []
    n = 20
    policies_dict = {}
    min_epsilon = 0.1
    max_epsilon = 1.0
    save_interval = 500 # for long runs

    for i_episode in range(num_episodes):
        if seed_env:
            random.seed(2)
        state = env.reset()
        np.random.seed()
        state = np.expand_dims(state, axis=0)
        if reward_manipulation:
            end_goal_positions = find_end_goal_positions(env.room_state)
        episode_reward = 0
        duration = 0

        if i_episode % save_interval == 0 and i_episode > 0:
            mlflow.pytorch.log_model(policy_net, f"{run_name}_episode_{i_episode}")

        # If we have passed n+1 episodes, check if we have reached convergence
        if i_episode > n+1 and check_convergence(i_episode, episode_rewards, episode_durations):
            mlflow.log_metric("Num episodes to converge",i_episode)
            mlflow.pytorch.log_model(policy_net, run_name)

            policy_net_half_state_dict = policies_dict[f'episode_{i_episode//2}']
            policy_net_half = model(env.observation_space.shape, env.action_space.n).to(device)
            policy_net_half.load_state_dict(policy_net_half_state_dict)
            mlflow.pytorch.log_model(policy_net_half, f'{run_name}_half')
            break
        for t in range(max_num_steps_per_episode):
            if reward_manipulation:
                box_positions = find_box_positions(env.room_state)

            action = select_action(state, env, policy_net, epsilon=epsilon)
            observation, reward, done,  _ = env.step(action.item())
            reward = torch.tensor([reward], device=device)
            if done:
                next_state = None
                if reward_manipulation:
                    next_box_positions = None
                    reward += 1
            else:
                next_state = np.expand_dims(observation, axis=0)
                if reward_manipulation:
                    next_box_positions = find_box_positions(env.room_state)
            if reward_manipulation and not done:
                reward = apply_reward_manipulation(reward, box_positions, next_box_positions, end_goal_positions, done)
            # Store the transition in memory
            memory.push(state, action, next_state, reward)
            state = next_state

            # Optimize the policy network
            optimize_model(batch_size, gamma, optimizer, policy_net, target_net, memory)
            episode_reward += reward.item()
            duration += 1

            # Update of the policy and target network Ws
            target_net_state_dict = target_net.state_dict()
            policy_net_state_dict = policy_net.state_dict()
            for key in policy_net_state_dict:
                target_net_state_dict[key] = policy_net_state_dict[key]*tau + target_net_state_dict[key]*(1-tau)
            target_net.load_state_dict(target_net_state_dict)



            # Apply epsilon decay iff the episode was successful:
            if epsilon_decay_exp:
                epsilon = max(min_epsilon, epsilon * epsilon_decay_factor)
            elif epsilon_decay_linear:
                epsilon = max(min_epsilon, max_epsilon - (i_episode / epsilon_decay_factor) * (max_epsilon - min_epsilon))

            if done:
                episode_rewards.append(episode_reward)
                episode_durations.append(t + 1)
                policy_state = {k: v.cpu() for k, v in policy_net.state_dict().items()}
                policies_dict.update({f'episode_{i_episode}': policy_state})
                if i_episode % n == 0:
                    clear_output()
                    print(f"On episode {i_episode}, the average reward for the past {n} episodes is {round(np.mean(episode_rewards[-n:]),2)}")
                    print(f"The average duration of episode in the past {n} is {round(np.mean(episode_durations[-n:]),2)}")
                    plot_results(episode_durations, duration_mode=True, run_name=run_name)
                    plot_results(episode_rewards, run_name=run_name)
                break
        mlflow.log_metric("Number of steps",t+1,step=i_episode)
        mlflow.log_metric("Sum of rewards",episode_reward,step=i_episode)

    return episode_durations, episode_rewards, policies_dict

# %%
def run_experiment(sokoban, model, run_name, num_episodes, optimizer_class, lr, epsilon, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear, batch_size, reward_manipulation, memory_size, seed_env):
    env = create_env(sokoban)
    memory = ReplayMemory(memory_size)
    n_actions = env.action_space.n
    if seed_env:
        random.seed(2)
    state = env.reset()
    np.random.seed()
    n_observations = len(state)
    policy_net = model(env.observation_space.shape, n_actions).to(device)
    target_net = model(env.observation_space.shape, n_actions).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    if optimizer_class == 'AdamW':
        optimizer = optim.AdamW(policy_net.parameters(), lr=lr, amsgrad=True)
    elif optimizer_class == 'SGD':
        optimizer = optim.SGD(policy_net.parameters(), lr=lr, momentum=0.9)
    elif optimizer_class == 'RMSprop':
        optimizer = optim.RMSprop(policy_net.parameters(), lr=lr, alpha=0.99, eps=1e-08)
    else:
        raise ValueError(f"Unsupported optimizer class: {optimizer_class}")
    max_num_steps_per_episode = 500
    episode_durations, episode_rewards, policies_dict = train(env, model, run_name, memory, optimizer, policy_net, target_net, batch_size, num_episodes, max_num_steps_per_episode,
                                                              epsilon_decay_factor=epsilon_decay_factor, epsilon_decay_exp=epsilon_decay_exp, epsilon_decay_linear=epsilon_decay_linear,
                                                              epsilon=epsilon, reward_manipulation=reward_manipulation, seed_env=seed_env)
    return episode_durations, episode_rewards, policies_dict

# %%
def run_experiments(sokoban, model, num_episodes=500, experiment_id=2, optimizer_classes=['AdamW', 'RMSprop'], lrs=[0.001, 0.0001], epsilons=[0.1, 0.25, 0.6, 1.0],
                    reward_manipulation_options=[False, True], batch_sizes=[128, 64, 32], epsilon_decay_factor=None, epsilon_decay_exp=False, epsilon_decay_linear=False, memory_size=50000, seed_env=True):
    for reward_manipulation in reward_manipulation_options:
        for lr in lrs:
            for optimizer_class in optimizer_classes:
                for batch_size in batch_sizes:
                    for epsilon in epsilons:
                        epsilon_decay = (epsilon_decay_exp or epsilon_decay_linear) and (epsilon_decay_factor > 0.5)
                        run_name = f"{optimizer_class}_{lr}_{epsilon}_decay_{epsilon_decay}_reward_manip_{reward_manipulation}_{batch_size}"
                        with mlflow.start_run(experiment_id=experiment_id, run_name=run_name):
                            params = {
                                "optimizer_class": optimizer_class,
                                "lr": lr,
                                "epsilon": epsilon,
                                "epsilon_decay": epsilon_decay,
                                "batch_size": batch_size,
                                "reward_manipulation": reward_manipulation
                            }
                            if epsilon_decay:
                                params["epsilon_decay_factor"] = epsilon_decay_factor
                                mlflow.log_params(params)
                            else:
                                mlflow.log_params(params)
                            env = copy.deepcopy(sokoban)
                            episode_durations, episode_rewards, policies_dict = run_experiment(sokoban, model, run_name, num_episodes, optimizer_class, lr,
                                                                                               epsilon, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear,
                                                                                               batch_size, reward_manipulation, memory_size, seed_env)
                            print('Complete')
                            plot_results(episode_durations, duration_mode=True, add_mean_and_std=True, log=True, run_name=run_name)
                            plot_results(episode_rewards, add_mean_and_std=True, log=True, run_name=run_name)

# %% [markdown]
# # Feeling the Env

# %%
def create_model_attempt(env, model, video_filename, use_seed=True):
    env = create_env(env)
    start_time = time.time()
    done = False
    iter = 0
    if use_seed:
        random.seed(2)
    state = env.reset()
    np.random.seed()
    state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device) # Assuming state is a NumPy array


    with imageio.get_writer(video_filename, fps=10) as video:
        while (iter < 10) or not done:
            time_passed = int(time.time() - start_time)
            if done or time_passed > 3:
                video.append_data(env.render(mode='rgb_array'))
                break
            iter += 1

            # Use the trained model to select the action
            with torch.no_grad():
                action = model(state).max(1)[1].view(1, 1).item()

            video.append_data(env.render(mode='rgb_array'))
            next_state, reward, done, info = env.step(action)

            # Update the state
            state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)

# %% [markdown]
# ## EX1 - FIX SCENARIO -  PUSH & PULL - ONE BOX

# %%
#=============== DO NOT DELETE ===============
random.seed(2)
sok = PushAndPullSokobanEnv(dim_room=(7, 7),num_boxes=1 ,max_steps=500)
# ============================================

# %%
random.seed(2)
sok.reset()
screen = sok.render(mode='rgb_array')
plt.imshow(sok.render('rgb_array'))
observation, reward, done, _ = sok.step(1)
print_env_det(sok)
# Out:
# Observation space: Box(0.0, 255.0, (112, 112, 3), float32)
# Action space: Discrete(13)
# Player position:[2 4]
# Box location: (3, 4)

# %% [markdown]
# ### EX1 - Video test

# %%
env = sok
start_time = time.time()
done = False
iter = 0
video_filename = 'imageio.mp4'
with imageio.get_writer(video_filename, fps=10) as video:
  while (iter < 10) or not done:
    time_passed = int(time.time() - start_time)
    if done or time_passed > 3:
      break
    iter +=1
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    video.append_data(env.render(mode='rgb_array'))
embed_mp4(video_filename)

# %% [markdown]
# ### DQN Experiments

# %%
# %%script echo skipping
# experiment_id = 2
# num_episodes = 500
# optimizer_classes = ['AdamW', 'RMSprop']
# lrs = [0.001, 0.0001]
# epsilons = [0.1, 0.25, 0.6, 1.0]
# reward_manipulation_options = [False, True]
# batch_sizes = [128, 64, 32]
# epsilon_decay_factor = 0.98
# epsilon_decay_exp = True
# epsilon_decay_linear = False
# memory_size = 50_000
# seed_env = True
# model = DQN
#
# run_experiments(sok, model, num_episodes, experiment_id, optimizer_classes, lrs, epsilons, reward_manipulation_options,
#                 batch_sizes, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear, memory_size, seed_env)
# Out:
# skipping

# %% [markdown]
# To see all of the experiments run above:
# [EX1 DQN Experiments](https://dagshub.com/aviv.ples/sokoban-rl.mlflow/#/experiments/2)

# %% [markdown]
# ### EX1 Solved - DQN Solution
# Fastest convergence with the least amount of steps (11):
#
# * optimizer = AdamW
# * Learning Rate = 0.001
# * Initial Epsilon = 1.0
# * Epsilon Decay = True
# * Reward Maniplation = True
# * Batch Size = 128

# %%
mlflow.artifacts.load_image('mlflow-artifacts:/b51cd1a9db2c4dc0a42ef95af78d51a4/7a4ee1c7c61847e9ae0f736dd4d784fd/artifacts/AdamW_0.001_1.0_decay_True_reward_manip_True_128_Rewards.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2000x1200>

# %% [markdown]
# #### Half Way of Convergence

# %%
logged_model_ex1_dqn_half = 'runs:/7a4ee1c7c61847e9ae0f736dd4d784fd/AdamW_0.001_1.0_decay_True_reward_manip_True_128_half'
model_ex1_dqn_half = mlflow.pytorch.load_model(logged_model_ex1_dqn_half, map_location=device)
# Out:
# 2023/08/22 14:44:39 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
video_filename = 'ex1_dqn_half.mp4'

create_model_attempt(sok, model_ex1_dqn_half, video_filename)
embed_mp4(video_filename)
# Out:
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# #### Convergence

# %%
logged_model_ex1_dqn = 'runs:/7a4ee1c7c61847e9ae0f736dd4d784fd/AdamW_0.001_1.0_decay_True_reward_manip_True_128'
model_ex1_dqn = mlflow.pytorch.load_model(logged_model_ex1_dqn, map_location=device)
# Out:
# 2023/08/22 14:44:51 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
video_filename = 'ex1_dqn.mp4'

create_model_attempt(sok, model_ex1_dqn, video_filename)
embed_mp4(video_filename)
# Out:
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# ### Dueling DQN Experiments

# %%
# %%script echo skipping
# experiment_id = 7
# num_episodes = 500
# optimizer_classes = ['AdamW', 'RMSprop']
# lrs = [0.001, 0.0001]
# epsilons = [0.1, 0.25, 0.6, 1.0]
# reward_manipulation_options = [False, True]
# batch_sizes = [128, 64, 32]
# epsilon_decay_factor = 0.98
# epsilon_decay_exp = True
# epsilon_decay_linear = False
# memory_size = 50_000
# seed_env = True
# model = DuelingDQN
#
# run_experiments(sok, model, num_episodes, experiment_id, optimizer_classes, lrs, epsilons, reward_manipulation_options,
#                 batch_sizes, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear, memory_size, seed_env)
# Out:
# skipping

# %% [markdown]
# To see all of the experiments run above:
# [EX1 Dueling DQN Experiments](https://dagshub.com/aviv.ples/sokoban-rl.mlflow/#/experiments/7)

# %% [markdown]
# It can be seen that using the Dueling DQN achieves convergence in 83% of the experiments, compared to the DQN achieves convergence only in 44% of the Experiments

# %% [markdown]
# ### EX1 Solved - Dueling DQN Solution
# Fastest convergence with the least amount of steps (11):
#
# * optimizer = RMSprop
# * Learning Rate = 0.001
# * Initial Epsilon = 0.1
# * Epsilon Decay = False
# * Reward Maniplation = True
# * Batch Size = 32

# %%
mlflow.artifacts.load_image('mlflow-artifacts:/7297879f46f94c2fb85208543df51c23/244dd5d10dde4b3d93dcb43a282aef7f/artifacts/RMSprop_0.001_0.1_decay_True_reward_manip_True_32_Rewards.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2000x1200>

# %% [markdown]
# #### Half Way of Convergence

# %%
logged_model_ex1_ddqn_half = 'runs:/244dd5d10dde4b3d93dcb43a282aef7f/RMSprop_0.001_0.1_decay_True_reward_manip_True_32_half'
model_ex1_ddqn_half = mlflow.pytorch.load_model(logged_model_ex1_ddqn_half, map_location=device)
# Out:
# 2023/08/22 14:44:56 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
video_filename = 'ex1_ddqn_half.mp4'

create_model_attempt(sok, model_ex1_ddqn_half, video_filename)
embed_mp4(video_filename)
# Out:
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# #### Convergence

# %%
logged_model_ex1_ddqn = 'runs:/244dd5d10dde4b3d93dcb43a282aef7f/RMSprop_0.001_0.1_decay_True_reward_manip_True_32'
model_ex1_ddqn = mlflow.pytorch.load_model(logged_model_ex1_ddqn, map_location=device)
# Out:
# 2023/08/22 14:44:59 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
video_filename = 'ex1_ddqn.mp4'

create_model_attempt(sok, model_ex1_ddqn, video_filename)
embed_mp4(video_filename)
# Out:
#   <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#   Your browser does not support the video tag.
#   </video>

# %% [markdown]
# ## EX2 - PUSH & PULL - ONE BOX

# %%
#=============== DO NOT DELETE ===============
sok_2 = PushAndPullSokobanEnv(dim_room=(7, 7),num_boxes=1 ,max_steps=500)
# ============================================

# %%
screen = sok_2.render(mode='rgb_array')
plt.imshow(sok_2.render('rgb_array'))
observation, reward, done, _ = sok_2.step(1)
print_env_det(sok_2)
# Out:
# Observation space: Box(0.0, 255.0, (112, 112, 3), float32)
# Action space: Discrete(13)
# Player position:[4 5]
# Box location: (4, 4)

# %% [markdown]
# ### EX2 - Video test

# %%
env = sok_2
start_time = time.time()
done = False
iter = 0
video_filename = 'imageio.mp4'
with imageio.get_writer(video_filename, fps=10) as video:
  while (iter < 10) or not done:
    time_passed = int(time.time() - start_time)
    if done or time_passed > 3:
      break
    iter +=1
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    video.append_data(env.render(mode='rgb_array'))
embed_mp4(video_filename)

# %%
# %%script echo skipping
# experiment_id = 5
# num_episodes = 10_000
# optimizer_classes = ['AdamW']
# lrs = [0.0001]
# epsilons = [1.0]
# reward_manipulation_options = [True]
# batch_sizes = [128]
# epsilon_decay_factor = 1_000
# epsilon_decay_exp = False
# epsilon_decay_linear = True
# memory_size = 500_000
# seed_env = False
# model = DuelingDQN
#
# run_experiments(sok_2, model, num_episodes, experiment_id, optimizer_classes, lrs, epsilons, reward_manipulation_options,
#                 batch_sizes, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear, memory_size, seed_env)
# Out:
# skipping

# %% [markdown]
# To see the experiment run above:
# [EX2 Dueling DQN Experiments](https://dagshub.com/aviv.ples/sokoban-rl.mlflow/#/experiments/5)

# %% [markdown]
# ### EX2 trained model - Dueling DQN Solution
#
# * optimizer = AdamW
# * Learning Rate = 0.0001
# * Initial Epsilon = 1.0
# * Epsilon Decay = True
# * Reward Maniplation = True
# * Batch Size = 128

# %%
runID = '4c4388ad440444b79c954719f5d5066e'
metricKey = 'Sum of rewards'

client = mlflow.tracking.MlflowClient(tracking_uri=os.getenv('MLFLOW_TRACKING_URI'))

metrics = client.get_metric_history(runID, metricKey)

# %%
i = 9500
last_100 = [x.value for x in metrics[i-100:i]]
plot_results(last_100, add_mean_and_std=True, run_name='EX2 DDQN Last 100 Episodes')

# %% [markdown]
# #### Checkpoint after 9500 episodes

# %%
logged_model_ex2_ddqn = 'runs:/4c4388ad440444b79c954719f5d5066e/AdamW_0.0001_1.0_decay_True_reward_manip_True_128_episode_9500'
model_ex2_ddqn = mlflow.pytorch.load_model(logged_model_ex2_ddqn, map_location=device)
# Out:
# 2023/08/22 14:45:08 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
won = 0
env_2 = create_env(sok_2)

for i in range(100):
    state = env_2.reset()
    np.random.seed()
    start_time = time.time()
    done = False
    iter = 0
    state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)

    while (iter < 20) or not done:
        time_passed = int(time.time() - start_time)
        if done or time_passed > 3:
            won += 1
            break
        iter += 1

        with torch.no_grad():
            action = model_ex2_ddqn(state).max(1)[1].view(1, 1).item()

        # Take the step in the environment
        next_state, reward, done, info = env_2.step(action)

        # Update the state
        state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)
    if i % 10 == 0 and i > 0:
        print(f"After {i} iterations, we have solved {won} enviornments.")
# Out:
# After 10 iterations, we have solved 1 enviornments.
# After 20 iterations, we have solved 2 enviornments.
# After 30 iterations, we have solved 3 enviornments.
# After 40 iterations, we have solved 4 enviornments.
# After 50 iterations, we have solved 4 enviornments.
# After 60 iterations, we have solved 5 enviornments.
# After 70 iterations, we have solved 5 enviornments.
# After 80 iterations, we have solved 5 enviornments.
# After 90 iterations, we have solved 5 enviornments.

# %%
print(f"The policy solved the game in {won}% of the times")
# Out:
# The policy solved the game in 5% of the times

# %% [markdown]
# ## EX3 - PUSH & PULL - TWO BOXES

# %%
#=============== DO NOT DELETE ===============
sok_3 = PushAndPullSokobanEnv(dim_room=(7, 7),num_boxes=2 ,max_steps=500)
# ============================================

# %%
screen = sok_3.render(mode='rgb_array')
plt.imshow(sok_3.render('rgb_array'))
observation, reward, done, _ = sok_3.step(1)
print_env_det(sok_3)
# Out:
# Observation space: Box(0.0, 255.0, (112, 112, 3), float32)
# Action space: Discrete(13)
# Player position:[5 2]
# Box location: (3, 3)

# %% [markdown]
# ### EX3 - Video test

# %%
env = sok_3
start_time = time.time()
done = False
iter = 0
video_filename = 'imageio.mp4'
with imageio.get_writer(video_filename, fps=10) as video:
  while (iter < 10) or not done:
    time_passed = int(time.time() - start_time)
    if done or time_passed > 3:
      break
    iter +=1
    action = env.action_space.sample()
    observation, reward, done, info = env.step(action)
    video.append_data(env.render(mode='rgb_array'))
embed_mp4(video_filename)

# %%
# %%script echo skipping
# experiment_id = 6
# num_episodes = 10_000
# optimizer_classes = ['AdamW']
# lrs = [0.0001]
# epsilons = [1.0]
# reward_manipulation_options = [True]
# batch_sizes = [128]
# epsilon_decay_factor = 1_000
# epsilon_decay_exp = False
# epsilon_decay_linear = True
# memory_size = 500_000
# seed_env = False
# model = DuelingDQN
#
# run_experiments(sok_3, model, num_episodes, experiment_id, optimizer_classes, lrs, epsilons, reward_manipulation_options,
#                 batch_sizes, epsilon_decay_factor, epsilon_decay_exp, epsilon_decay_linear, memory_size, seed_env)
# Out:
# skipping

# %% [markdown]
# To see the experiment run above:
# [EX3 Dueling DQN Experiments](https://dagshub.com/aviv.ples/sokoban-rl.mlflow/#/experiments/6)

# %% [markdown]
# ### EX3 trained model - Dueling DQN Solution
#
# * optimizer = AdamW
# * Learning Rate = 0.0001
# * Initial Epsilon = 1.0
# * Epsilon Decay = True
# * Reward Maniplation = True
# * Batch Size = 128

# %%
runID = '88cd4bee58534f4188cb162ec4009163'
metricKey = 'Sum of rewards'

client = mlflow.tracking.MlflowClient(tracking_uri=os.getenv('MLFLOW_TRACKING_URI'))

metrics = client.get_metric_history(runID, metricKey)

# %%
i = 9500
last_100 = [x.value for x in metrics[i-100:i]]
plot_results(last_100, add_mean_and_std=True, run_name='EX3 DDQN Last 100 Episodes')

# %% [markdown]
# #### Checkpoint after 9500 episodes

# %%
logged_model_ex3_ddqn = 'runs:/88cd4bee58534f4188cb162ec4009163/AdamW_0.0001_1.0_decay_True_reward_manip_True_128_episode_9500'
model_ex3_ddqn = mlflow.pytorch.load_model(logged_model_ex3_ddqn, map_location=device)
# Out:
# 2023/08/22 14:47:29 WARNING mlflow.pytorch: Stored model version '1.13.1+cu117' does not match installed PyTorch version '2.0.1+cu118'

# %%
won = 0
env_3 = create_env(sok_3)

for i in range(100):
    state = env_3.reset()
    np.random.seed()
    start_time = time.time()
    done = False
    iter = 0
    state = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)

    while (iter < 20) or not done:
        time_passed = int(time.time() - start_time)
        if done or time_passed > 3:
            won += 1
            break
        iter += 1

        with torch.no_grad():
            action = model_ex3_ddqn(state).max(1)[1].view(1, 1).item()

        # Take the step in the environment
        next_state, reward, done, info = env_3.step(action)

        # Update the state
        state = torch.tensor(next_state, dtype=torch.float32).unsqueeze(0).to(device)
    if i % 10 == 0 and i > 0:
        print(f"After {i} iterations, we have solved {won} enviornments.")
# Out:
# After 10 iterations, we have solved 0 enviornments.
# After 20 iterations, we have solved 0 enviornments.
# After 30 iterations, we have solved 0 enviornments.
# After 40 iterations, we have solved 0 enviornments.
# After 50 iterations, we have solved 0 enviornments.
# After 60 iterations, we have solved 0 enviornments.
# After 70 iterations, we have solved 0 enviornments.
# After 80 iterations, we have solved 0 enviornments.
# After 90 iterations, we have solved 0 enviornments.

# %%
print(f"The policy solved the game in {won}% of the times")
# Out:
# The policy solved the game in 0% of the times
